# %% [markdown]
# # Part 1. Introduction
# The 2019 study, Changes in human peripheral blood mononuclear cell (HPBMC) populations and T-cell subsets associated with arsenic and polycylic aromatic hydrocarbon exposures in a Bangladesh cohort, done by Fredine T. Lauer et al., built off of a previous study that found Arsenic and polycyclic aromatic hydrocarbon exposures were associated with T cell proliferation and cytokine production in a cohort of males from Bangladesh. In this study, they investigated the possible connections between Arsenic and polycyclic aromatic hydrocarbon exposures with lymphoid cell populations in human peripheral blood mononuclear cells, and the potential effects of this exposure on the differentiation and activation of functional cell subsets including T helper cells, T regulatory cells, and anti-CD3/anti-CD28 activation.

# %% [markdown]
# # Part 2. Relate Research questions, data, and figures
#
# Part 2.1: My Part 2 Submission with modifications
# Section 1: Data & Research Questions
# Data Set
# This dataset is connected to the research article, Changes in human peripheral blood mononuclear cell (HPBMC) populations and T-cell subsets associated with arsenic and polycyclic aromatic hydrocarbon exposures in a Bangladesh cohort. The researchers were Fredine T. Lauer, Faruque Parvez, Pam Factor-Litvak, Xinhua Liu, Regina M. Santella, Tariqul Islam, Mahbubul Eunus, Nur Alam, A. K. M. Rabiul Hasan, Mizanour Rahman, Habibul Ahsan, Joseph Graziano, and Scott W. BurchieI.
#
# In this study, the hope was to add to the little data there is available regarding the effects of combined exposure to environmental arsenic (As) and polycyclic aromatic hydrocarbons (PAHs), specifically immunotoxicity to humans. To do this, 197 Bangladesh men were selected based on their exposure to As from drinking water and their cigarette smoking status (no women were studied because an insufficient amount were smokers). By design, 49% of the participants were smokers and 49% were exposed to water with arsenic levels over 50 ppb, or levels deemed unsafe in Bangladesh (the WHO recommended  limit is 10 ppb), creating the 197 rows/observations in the dataset. These men were surveyed and had blood and urine samples collected and the present immune cells were measured along with the T-helper cell subsets via an ex vivo activation method.This resulted in the 26 features that make up the dataset and are used throughout the paper: age (years), BMI, smoking status (yes or no), totally urinary adjusted for creatinine (μg UAs/g creatinine), PAH exposure (per 108  nucleotides), the percent of T cells, T-helper cells, cytotoxic T lymphocytes, T memory cells, monocytes, non-monocyte (dose-dependent), B cells, activated B cells, natural killer cells, natural killer T cells, cells expressing the IL-7 receptor alpha, T regulatory cells, CD4 cells, Interferon cells, Interleukin-4 cells, interleukin-17 cells, stimulated CD4+ cells, stimulated CD3+ cells, and stimulated cells that are living.
#
# There were two other features used in the dataset that were essentially unmentioned in the report: water arsenic exposure and viability. These two features, while not directly applicable to the measurements used throughout the charts and report, are good explanations for any outliers. Any measurements that appear abnormal are likely explainable from one or both of these additional features.
#
#
# Research Questions
#
# The research question of this article was whether there are associations between As and PAH exposures with lymphoid cell populations in the peripheral blood mononuclear (PBMC) cells of humans. The objective was to examine alterations in the differentiation and activation of B and T cells. The hypothesis was that because large PAHs are carcinogenic and harmful to DNA, they will act synergistically with As in people. The features that were selected for this allow the assessment of association between As and PAH exposure, both separately and in combination, with damage to cell surface markers on PBMC and T-helper cell subsets.
#
# Another question that could be assessed using this data is what changes in immune cell populations are unique to those exposed to harmful amounts of both As and PAH? Are there any immunotoxic consistencies that did not occur in anyone who measured safe levels in at least one of the carcinogens? Perhaps this could be a step in the direction of better understanding the coexistence of As and PAHs.
#
# Section 2: Visualizations & Data Summaries
#
# First Figure: Figure 1 from Lauer et al., 2019
# ![image.png](data:image/png;base64,...)
#
#
# Figure 1 depicts the association between urinary arsenic concentrations and different cell surface markers. Each datapoint in figure one represents an observation and the solid lines represent the estimated mean outcome of living cells adjusted for other variables along with those in the model. The x axis for all four graphs is the amount of urinary arsenic excreted and the y axis is the percent of living cells for different markers. The four markers graphed are Th cells in graph A, monocytes(CD14+) in graph B, monocytes (CD14+ CD16+) in graph C, and NKT cells in graph D.
# As shown in graph A, Th cells were found to increase with As exposure while both types of monocytes and NKT cells (graphs B,C,D) were non-monotonic. The graphs act as a prime example of the apparent  inconsistency when not all the proper factors are considered. All four graphs have completely unique mean estimate lines due to how uniquely each marker is affected by As and PAH exposure.
#
# Second Figure: Figure 4 from Lauer et al., 2019
#
#
#
# ![figure 4.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
#
#
# This is Figure 4 from the paper. The PAH-DNA Adducts are assigned to all four of the charts x axis and the percent of cells that remain living is all four y axis, however the type of cell is different for each chart. Chart A’s y axis is the percent of Th cells that remained living after exposure, chart B’s is the percent of Th1 cells that remained living, chart c is the percent of Th2 cells that remained living, and chart D is the percent of Th17 cells that remained living. Each datapoint represents a single observation and the solid line represents what would be the mean outcome that would be estimated based on other variables. A noticeable decrease in the percentage of Th cells was shown at high PAH-DNA levels. At lower levels of exposure for all four cells, after taking into consideration age, BMI, smoking status and UAs/Cr, non-monotonic associations appear. This figure is described as a good depiction of the complexity of the side effects faced from co-exposure to As and PAHs.
#
# These two plots along with the tables throughout the article show their several findings including that As exposure could be associated with an increase in the percentage of Th cells, and a trend toward non-monotonic increases with CD14+ monocytes and CD14+CD16 cells. There was also a non-monotonic association found among the urinary arsenic levels and natural killer cells which was not in any of the previous studies. Additionally, PAH  adducts were found to have a negative association in those with T- and T-memory  cell phenotype, which was also consistent with previous studies. All together, this suggests that non-genotoxic signaling pathways may not be predicted based on in vitro genotoxicity studies of DNA damage and As interactions with PAHs.
# Another figure or table that would be useful for understanding this data
#
# Figures that I believe would be beneficial would be scatter plots that have the Arsenic exposure values (“Water_As) on the x axis and each other feature on the y axis, resulting in 25 scatter plots. Having these scatter plots will provide a visual representation of how affected by Arsenic each of the cell surface markers and T cell subsets are. The same could be done, but instead with the PAH exposure levels (“PAH_DNA_adducts) on the x axis to also see to what extent each of the cell surface markers and T cell subsets are influenced by PAH exposure.
#
#
# In the corresponding dataset to this study, there are 197 rows and 27 columns, not including the column titles. This corresponds to the 197 observations, each listed as a SampleID, along with their 26 other features. The introduction states that there were 197 chosen participants, which correlates with the 197 observations/unique Sample ID’s/rows. Additionally, if you calculate the mean of each column/feature in excel, the values exactly match up with the values in Table 1, confirming that these values are used in all of the tables and graphs throughout the paper and that the columns each correspond to a single feature and the rows each correspond to a single observation.
#
# The data is formatted with tab as the delimiter and no quotations or apostrophes around any data values. This was confirmed using the Text to Columns data tool function on excel.
#
#
# Part 2.2: Summary of Improvements Made
#
# When I transferred my rough draft information to the document I submitted for Part 2, the information regarding the rows, columns, and delimiters did not make it, so I added in a paragraph containing the information pertaining to all three. Additionally, my recommendation for what graphs or tables that would be beneficial was vague and insufficient, so I replaced that paragraph entirely. I also completely changed my answer to this portion from saying that histograms would be useful visualizations to saying that certain set of scatter plots (ones that show the relation between contaminant exposure and each cell type’s response) could convey useful information.

# %% [markdown]
# # Part 3. Data Cleaning and Exploration
#
# Part 3.1 Load and clean data
# To obtain this datafile you go to https://figshare.com/articles/dataset/Changes_in_human_peripheral_blood_mononuclear_cell_HPBMC_populations_and_T-cell_subsets_associated_with_arsenic_and_polycyclic_aromatic_hydrocarbon_exposures_in_a_Bangladesh_cohort/8144492, download the excel file, and save it as a csv file with the name "pah_as_exposure" in the "Lauer_et_al" directory.
#
# One of the things I noticed  was that in addition to the 27 columns of data, there were four additoinal columns of information that was not part of the data. It was a table of additonal information, specifically what markers pertained to each of the cell markers and intracellular stains. Because of this, I had to figure out what command limits which columns in a csv file get assigned to a variable. Using https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html, I figured out that I needed to first create a list of the column numbers that I want to use and then use the usecols function to tell it which columns are the proper ones(which columns were necesary was determined by looking at the excel file). This command is done in the same location as, and was used along with, the index column command ("index_col = 0"). Below is how this appeared:
#
# ```
# import pandas as pd
# useful_cols= list(range(27))
# pah_as_exposure = pd.read_csv("/content/drive/MyDrive/pah_as_exposure.csv", usecols=useful_cols, index_col=0)
# ```

# %% [markdown]
# Below is the "head" of this dataframe:

# %%
import pandas as pd
useful_cols= list(range(27))
pah_as_exposure = pd.read_csv("/content/drive/MyDrive/pah_as_exposure.csv", usecols=useful_cols, index_col=0)
pah_as_exposure.head()
# Out:
#               UAsgmcr  PAH_DNA_adducts  Viability  T cell    Th   CTL  Tmem  \
# SampleID
# VS0010     431.211499              3.6       88.2    52.8  24.4  21.8  21.9
# VS0011     869.565217              4.2       89.9    62.0  22.1  33.0  31.2
# VS0012    1748.768473              4.1       88.4    46.5  28.4  14.7  30.1
# VS0014    4071.856287              1.2       91.4    53.2  31.5  16.5  22.1
# VS0015     746.987952              3.5       87.3    48.1  19.6  25.2  31.2
#
#           MonoClass  NonMono  Bcell  ...  IFNg  IL-4  IL-17A  StimCD4  \
# SampleID                             ...
# VS0010         8.16     1.09   9.56  ...  5.54  1.90    4.15     27.5
# VS0011         9.89     0.66  10.10  ...  4.70  2.53    3.17     20.9
# VS0012         5.99     1.59  17.10  ...  6.13  2.77    6.69     28.3
# VS0014         9.61     1.99  15.10  ...  3.62  4.89   14.00     25.5
# VS0015         5.69     0.39   9.54  ...  3.72  1.82    3.88     14.3
#
# ...

# %% [markdown]
# Part 3.2 Describe data numerically
#
# Below is the code to obtain the shape of this dataframe which tells us the number of rows and columns in this dataset
#
#
# ```
# pah_as_exposure.shape
# ```
# The resulting output of this code, as shown below, tells us the number of rows, 197, and columns, 26, not including the column names as that row is not an observation, and when the SampleID column is the index column.

# %%
pah_as_exposure.shape
# Out:
# (197, 26)

# %% [markdown]
# Two selected features: "Age" and "Water_As"
#
# For each feature, because the column is entirely made up of numbers, I expect the describe function to calculate the minimum, maximum, median, Q1, Q3, and standard deviation of the values in that column.

# %%
pah_as_exposure['Age'].describe()
# Out:
# count    197.000000
# mean      51.827411
# std        6.422272
# min       36.000000
# 25%       47.000000
# 50%       52.000000
# 75%       57.000000
# max       65.000000
# Name: Age, dtype: float64

# %%
pah_as_exposure['PAH_DNA_adducts'].describe()
# Out:
# count    181.000000
# mean       2.216022
# std        1.422446
# min        0.500000
# 25%        1.300000
# 50%        1.800000
# 75%        3.000000
# max        8.000000
# Name: PAH_DNA_adducts, dtype: float64

# %% [markdown]
# For the PAH_DNA_adducts feature, 181 observations have a recorded value. The mean concetration in  of all these observations is 2.22 per 100 million nucleotides .
#
# For the Water_As feature, all 197 observations have a recorded value. The mean age is 51.83 years.
#
# All of the values I predicted would be in the describe funciton were present. The only difference was that I did not predict it would have the count value and it does.

# %% [markdown]
# 3.3 Visualizations
# I want to make a box plot for each of the chosen features, Age and PAH exposure. Boxplot is useful for both of these features to give a visual representation of the variability in the values of both features.

# %%
pah_as_exposure.columns #having the avialble column names allows us to ensure we are assinging the feature to each axis we mean to
# Out:
# Index(['UAsgmcr', 'PAH_DNA_adducts', 'Viability', 'T cell', 'Th', 'CTL',
#        'Tmem', 'MonoClass', 'NonMono', 'Bcell', 'ActB', 'NK', 'NKT', 'IL7Ra',
#        'CD4', 'Treg', 'IFNg', 'IL-4', 'IL-17A', 'StimCD4', 'StimCD3',
#        'StimLive', 'Age', 'Water_As', 'eversmoke', 'BMI'],
#       dtype='object')

# %%
import seaborn as sns
sns.boxplot(x="Age", data=pah_as_exposure)
#The .boxplot portion of this line of code estblishes that we are looking for a boxplot. the x= component tells it to assign the Age column to
#the x axis and the data= command tells it to obtain this data from the path_as_exposure dataframe
#The furthest left vertical line represents the mimum value generated from the describe function. The next vertical line moving to the
#right represents Q1, the next the median, followed by Q3, and finally the maximum. This garph also communicates that there are no outleirs
#It is evident that the researcers intentionally and effectively got as close as possible to an equal amount of subjects of all ages.
#This graph also appears to match the minimum, maximum, Q1, median, and Q3 values given by the describe function. This infomration proivdes
#the ability to rule out the connection between age and cell presence as a possible effect or source of error when looking at all cell types
# which is required in order to answer the researchers' hypothesis
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x="PAH_DNA_adducts", data=pah_as_exposure)
#This graph is gnerated in the exact same way as the first, just with a differnt feature on the x axis, this time the amount of PAHs present in the subjects
#This shows the varibaility in the amount of PAH present in the subjects' blood.
#This graph contains outliers and the boxes are not of equal size like the ones for Age, meaning the amount of PAH present in subejcts does not increase at a linear pace in relation to a single or set of variables.
#the vertical lines from left to right represent the minimum, Q1, meidan, Q3, and maximum, while the dots to the right each represent an outlier, all of which is listed in the describe fucntion except for the outlers
# Out:
# <Axes: xlabel='PAH_DNA_adducts'>
